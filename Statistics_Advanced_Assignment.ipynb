# %% [markdown]
# <a id='1'></a><center> <h3 style="background-color:orange; color:white" ><br>Telecommunication Industry Project<br></h3>

# %% [markdown]
# # Introduction
# This Jupyter notebook is part of your learning experience in the study of applied statistics.
#
# You will work with a data set that contains mobile phone prices and their specifications.
#
# **Dataset Columns Information**
#
# PID = a unique identifier for the phone model
#
# Blue = whether the phone has bluetooth support or not
#
# Wi_Fi = whether the phone has wifi support or not
#
# Tch_Scr = whether the phone has touch screen support or not
#
# Ext_Mem = whether the phone has external memory support or not
#
# Px_h = number of pixels in the vertical axis of the phone
#
# Px_w = number of pixels in the horizontal axis of the phone
#
# Scr_h = height of the screen of the phone in centimetres (cm)
#
# Scr_w = width of the screen of the phone in centimetres (cm)
#
# Int_Mem = internal memory of the phone measured in megabytes (MB)
#
# Bty_Pwr = maximum energy stored by the phone's battery measured in
# milli-Ampere-hours (mAh)
#
# PC = resolution of the primary camera measued in megapixels (MP)
#
# FC = resolution of the front camera measued in megapixels (MP)
#
# RAM = random access memory available in the phone measured in gigabytes (GB)
#
# Depth = depth of the mobile phone measured in centimetres (cm)
#
# Weight = weight of the mobile phone measured in grams (g)
#
# Price = selling price of the mobile phone in rupees

# %% [markdown]
# ## Task 1 - Load and study the data

# %% [markdown]
# Import the libraries that will be used in this notebook

# %%
# Load "numpy" and "pandas" for manipulating numbers and data frames
# Load "matplotlib.pyplot" and "seaborn" for data visualisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the csv file as pandas dataframe.

# %%
# Read in the "Dataset" file as a Pandas Data Frame
df = pd.read_csv("/content/Telecom Dataset (1).csv")
df
# Out:
#          PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w   PC  FC  \
# 0    AAB346A  yes   yes      no      no   780   460      3      1    2   2
# 1    AAC347I  yes   yes      no      no   780   560      2      1    4   2
# 2    BAB657J   no   yes      no      no   840   720      2      1    4   2
# 3    BBD456K   no   yes     yes      no  1280  1120      5      3    6   2
# 4    CCP761U   no   yes     yes      no  1280  1080      4      3    6   2
# 5    CCQ674K  yes    no      no      no  1280  1080      4      3    6   4
# 6    CTX123L  yes    no     yes      no  1390  1080      6      3    8   4
# 7    DFR256N  yes    no      no      no  2880  2120      8      6   12   8
# 8    DGS789M  yes   yes     yes     yes  2580  1920      6      3   32  16
# 9    ENG897N  yes   yes     yes     yes  2580  1980      5      3   64  32
# 10   EOP657N  yes   yes     yes     yes  2580  1920      6      3   32  16
# 11   ELS333L  yes   yes     yes     yes  2580  1920      8      6   64  32
# 12   ETT987D   no   yes     yes     yes  2580  1980      6      5   64  32
# 13   NAJ56GL   no   yes     yes      no  2880  2120      6      5   32  16
# 14   NBN329S  yes   yes     yes     yes  2380  1820      5      3   16   8
# 15   NSD450I   no    no     yes     yes  1980  1760     10      8   16  16
# 16   PDF768G   no    no     yes     yes  2580  1980      8      6   64  32
# 17   PDG234M   no    no     yes     yes  2880  2120      8      6    8   8
# 18   PEL111K   no    no     yes     yes  1980  1760      8      6   12   4
# 19  PNWD777L   no    no     yes     yes  2880  2120      4      3   24  12
# 20   POP857R   no   yes     yes     yes  1980  1760      4      3   32  16
# 21   QWR222Y   no   yes     yes     yes  2580  1980      8      6   64  32
# 22   QZR577O   no   yes     yes     yes  1440  1280      4      3    8   8
# 23   RAY344W   no   yes     yes     yes  2880  2120     10      8    8   4
# 24   RBZ451D   no   yes     yes     yes  1440  1280      6      4    8   4
# 25   SDO555G   no   yes     yes     yes  2580  1980      6      3   64  32
# 26   SET568R   no   yes     yes     yes  1980  1280      5      3    8   4
# 27   SFK567Y  yes   yes     yes     yes  2580  2120      8      6   64  16
# 28   SSD000L  yes   yes     yes     yes  2580  2120      8      6   64  32
# 29   SYL888P   no   yes     yes     yes  2580  2120      8      6   64  16
# 30   TVF078Y  yes   yes     yes     yes  2580  2120      8      6   64  32
# 31   TYQ109G   no   yes     yes     yes  2580  2120      8      6   32  16
# 32   TYS938L  yes   yes     yes     yes  2580  2120      8      6   64  32
# 33   TYU444Q   no   yes     yes     yes  2580  2120      8      6   64  32
# 34   TYY453J  yes   yes     yes     yes  2880  2120      6      3   64  32
# 35   ULI999T   no   yes     yes     yes  2440  2120      5      3   32  16
# 36   UST000T  yes   yes     yes     yes  2580  1980     10      8   64  32
# 37   USZ111S  yes   yes     yes     yes  2440  1980      5      3   48  32
# 38   VWV532Y  yes   yes     yes     yes  2580  1920      5      3   64  32
# 39   VYI666I  yes   yes     yes     yes  2440  1980      6      5   32  16
# 40   WER765T  yes   yes     yes     yes  2580  1980      5      3   64  32
# 41   WUV902Y  yes   yes     yes     yes  2580  1980      8      6   48  16
# 42   WZB298K  yes   yes     yes     yes  2580  1980      8      6   64  32
# 43   XKL901R   no   yes     yes     yes  2580  1980      8      6   32  16
# 44   XTL675G  yes   yes     yes     yes  2580  1980     10      8   64  32
# 45   XXV567F   no   yes     yes     yes  2580  1980      8      6   64  32
# 46   YTR67TY  yes   yes     yes     yes  2580  1980      4      3   64  32
# 47   ZDF789K  yes   yes     yes      no  2880  2520      8      6   64  32
# 48   ZEO567M  yes   yes     yes      no  2880  2520      8      6  128  64
# 49   ZZZ909X  yes   yes     yes      no  2880  2520      8      6  128  64
#
#     Int_Mem  Bty_Pwr  RAM  Depth  Weight   Price
# 0         8     2800    2      7     320    3297
# 1         8     3000    2      7     280    4500
# 2         8     3300    2      7     400    4898
# 3        32     3000    2      3     300    6900
# 4        16     3000    2      3     210    5600
# 5         8     2980    2      3     230    4990
# 6        32     3000    2      3     100   13400
# 7        32     3200    2      3      80   15600
# 8         8     2800    6      3     120   27688
# 9        64     4380    4      3     150   23456
# 10      128     2800    4      4     210   35460
# 11        8     4500    8      4     150   43980
# 12       64     4500    6      4     300   28700
# 13       64     2800    6      4     270   23600
# 14        8     2800    4      4      80   21972
# 15      128     3900    6      4     180   23456
# 16      128     3300    4      3     160   22650
# 17       64     2800    4      3     250   19806
# 18        8     4000    4      3     330   11388
# 19       64     2800    4      3     200   14350
# 20       16     2800    4      3     150   24560
# 21      128     4400    4      3     160   21350
# 22       64     2800    8      3     170   16999
# 23       16     4800    8      3     170   18900
# 24       32     2800    8      3     150   17890
# 25       64     4500    8      3     210   22000
# 26      128     4500    8      3     220   41320
# 27       32     4300    8      3     200   49899
# 28      512     4200    8      3     270   36555
# 29      256     5000    8      3     320   32459
# 30      512     4860    8      3      90   29999
# 31      256     3300    8      3     110   45899
# 32     1024     4860    8      3     120   46777
# 33      128     2800    8      3     120   45680
# 34      128     4400    8      4     150   61750
# 35       64     2800    8      4     210   42000
# 36       32     3000    4      4     240   34589
# 37      128     4800    4      4     230   42300
# 38       32     4860    8      4     310   39781
# 39       32     3200    4      4     180   33460
# 40      128     3000    4      4     120   34780
# 41      128     3400    4      3     140   28000
# 42     1024     5600    8      3     160   39000
# 43      256     3900    4      3     210   54320
# 44      512     4560    8      3     260   51230
# 45       64     2300    4      3     250   43990
# 46       64     2800    4      3     200   56000
# 47      512     5600   12      2      80   84566
# 48      512     5600   12      2     110   88999
# 49     1024     5600   12      2     130  149000

# %%
# Take a brief look at the data
df.head() # Displays the first few rows
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price
# 0        8     2800    2      7     320   3297
# 1        8     3000    2      7     280   4500
# 2        8     3300    2      7     400   4898
# 3       32     3000    2      3     300   6900
# 4       16     3000    2      3     210   5600

# %%
# Get the dimensions of the dataframe
df.ndim
# Out:
# 2

# %%
# Get the row names of the dataframe
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# Get the column names of the dataframe
feature_names = df.columns.tolist()
feature_names
# Out:
# ['PID',
#  'Blue',
#  'Wi_Fi',
#  'Tch_Scr',
#  'Ext_Mem',
#  'Px_h',
#  'Px_w',
#  'Scr_h',
#  'Scr_w',
#  'PC',
#  'FC',
#  'Int_Mem',
#  'Bty_Pwr',
#  'RAM',
#  'Depth',
#  'Weight',
#  'Price']

# %%
# Look at basic information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PID      50 non-null     object
#  1   Blue     50 non-null     object
#  2   Wi_Fi    50 non-null     object
#  3   Tch_Scr  50 non-null     object
#  4   Ext_Mem  50 non-null     object
#  5   Px_h     50 non-null     int64
#  6   Px_w     50 non-null     int64
#  7   Scr_h    50 non-null     int64
#  8   Scr_w    50 non-null     int64
#  9   PC       50 non-null     int64
#  10  FC       50 non-null     int64
#  11  Int_Mem  50 non-null     int64
#  12  Bty_Pwr  50 non-null     int64
#  13  RAM      50 non-null     int64
#  14  Depth    50 non-null     int64
#  15  Weight   50 non-null     int64
#  16  Price    50 non-null     int64
# dtypes: int64(12), object(5)
# memory usage: 6.8+ KB

# %% [markdown]
# Observations:
#
# There are 50 phones in the data set.
#
# There are 17 features in the data set including the "PID" feature which is used as the row index labels.
#
# There are no missing values in the data set.

# %% [markdown]
# <center>Let's try some logical operators to filter the data.<center>

# %% [markdown]
# ![](https://th.bing.com/th/id/R.0592084daa6518e4fae97f47217ec69e?rik=vNqmiaTVSSo54w&riu=http%3a%2f%2f2.bp.blogspot.com%2f-ujABms6N-Cg%2fTyYwShdTjnI%2fAAAAAAAAAAs%2fktPbHdifidc%2fs1600%2fLogical%2bOperators.PNG&ehk=ww1gl1HB2PcZwPQNHWRUvcQ631Q3mzyHSxL9G4zUKT4%3d&risl=&pid=ImgRaw&r=0,width=700,height=400)

# %% [markdown]
# ## Task 2 - Obtain the logical conditions for the features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem"

# %%
# Get the feature names of the dataframe
feature_names = df.columns.tolist()
feature_names
# Out:
# ['PID',
#  'Blue',
#  'Wi_Fi',
#  'Tch_Scr',
#  'Ext_Mem',
#  'Px_h',
#  'Px_w',
#  'Scr_h',
#  'Scr_w',
#  'PC',
#  'FC',
#  'Int_Mem',
#  'Bty_Pwr',
#  'RAM',
#  'Depth',
#  'Weight',
#  'Price']

# %%
# Let's tackle these features: "Blue", "Wi_Fi", "Tch_Scr", "Ext_Mem"
df.loc[:,["Blue","Wi_Fi","Tch_Scr","Ext_Mem"]]
# Out:
#    Blue Wi_Fi Tch_Scr Ext_Mem
# 0   yes   yes      no      no
# 1   yes   yes      no      no
# 2    no   yes      no      no
# 3    no   yes     yes      no
# 4    no   yes     yes      no
# 5   yes    no      no      no
# 6   yes    no     yes      no
# 7   yes    no      no      no
# 8   yes   yes     yes     yes
# 9   yes   yes     yes     yes
# 10  yes   yes     yes     yes
# 11  yes   yes     yes     yes
# 12   no   yes     yes     yes
# 13   no   yes     yes      no
# 14  yes   yes     yes     yes
# 15   no    no     yes     yes
# 16   no    no     yes     yes
# 17   no    no     yes     yes
# 18   no    no     yes     yes
# 19   no    no     yes     yes
# 20   no   yes     yes     yes
# 21   no   yes     yes     yes
# 22   no   yes     yes     yes
# 23   no   yes     yes     yes
# 24   no   yes     yes     yes
# 25   no   yes     yes     yes
# 26   no   yes     yes     yes
# 27  yes   yes     yes     yes
# 28  yes   yes     yes     yes
# 29   no   yes     yes     yes
# 30  yes   yes     yes     yes
# 31   no   yes     yes     yes
# 32  yes   yes     yes     yes
# 33   no   yes     yes     yes
# 34  yes   yes     yes     yes
# 35   no   yes     yes     yes
# 36  yes   yes     yes     yes
# 37  yes   yes     yes     yes
# 38  yes   yes     yes     yes
# 39  yes   yes     yes     yes
# 40  yes   yes     yes     yes
# 41  yes   yes     yes     yes
# 42  yes   yes     yes     yes
# 43   no   yes     yes     yes
# 44  yes   yes     yes     yes
# 45   no   yes     yes     yes
# 46  yes   yes     yes     yes
# 47  yes   yes     yes      no
# 48  yes   yes     yes      no
# 49  yes   yes     yes      no

# %%
# The children want phones that have the following: Bluetooth, WiFi, touch screen and external memory support
# Create a logical condition for this situation and store the logical values as "con1"

con1=(df['Blue']=="yes") & (df['Wi_Fi']=="yes") & (df['Tch_Scr']=="yes") & (df['Ext_Mem']=="yes")

#print(con1)

# Step 3: Iterate over 'con1' to display the values
for i in con1:
  if i ==True:
    print(i)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# Observations:
#
# The features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem" are binary in nature.
#
# The children want all these features, so the logical condition "con1" has been obtained accordingly.

# %% [markdown]
# ## Task 3 - Obtain the logical conditions for the features "Px_h" and "Px_w"

# %%
# Get the feature names of the dataframe
df.columns
# Out:
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price'],
#       dtype='object')

# %%
# Let's tackle these features: "Px_h", "Px_w
l1 = df.loc[:,["Px_h","Px_w"]]
l1
# Out:
#     Px_h  Px_w
# 0    780   460
# 1    780   560
# 2    840   720
# 3   1280  1120
# 4   1280  1080
# 5   1280  1080
# 6   1390  1080
# 7   2880  2120
# 8   2580  1920
# 9   2580  1980
# 10  2580  1920
# 11  2580  1920
# 12  2580  1980
# 13  2880  2120
# 14  2380  1820
# 15  1980  1760
# 16  2580  1980
# 17  2880  2120
# 18  1980  1760
# 19  2880  2120
# 20  1980  1760
# 21  2580  1980
# 22  1440  1280
# 23  2880  2120
# 24  1440  1280
# 25  2580  1980
# 26  1980  1280
# 27  2580  2120
# 28  2580  2120
# 29  2580  2120
# 30  2580  2120
# 31  2580  2120
# 32  2580  2120
# 33  2580  2120
# 34  2880  2120
# 35  2440  2120
# 36  2580  1980
# 37  2440  1980
# 38  2580  1920
# 39  2440  1980
# 40  2580  1980
# 41  2580  1980
# 42  2580  1980
# 43  2580  1980
# 44  2580  1980
# 45  2580  1980
# 46  2580  1980
# 47  2880  2520
# 48  2880  2520
# 49  2880  2520

# %%
# Create a new feature called "Px" which stores the total resolution of the screen
px = df["Px_h"]*df["Px_w"]
px
# Out:
# 0      358800
# 1      436800
# 2      604800
# 3     1433600
# 4     1382400
# 5     1382400
# 6     1501200
# 7     6105600
# 8     4953600
# 9     5108400
# 10    4953600
# 11    4953600
# 12    5108400
# 13    6105600
# 14    4331600
# 15    3484800
# 16    5108400
# 17    6105600
# 18    3484800
# 19    6105600
# 20    3484800
# 21    5108400
# 22    1843200
# 23    6105600
# 24    1843200
# 25    5108400
# 26    2534400
# 27    5469600
# 28    5469600
# 29    5469600
# 30    5469600
# 31    5469600
# 32    5469600
# 33    5469600
# 34    6105600
# 35    5172800
# 36    5108400
# 37    4831200
# 38    4953600
# 39    4831200
# 40    5108400
# 41    5108400
# 42    5108400
# 43    5108400
# 44    5108400
# 45    5108400
# 46    5108400
# 47    7257600
# 48    7257600
# 49    7257600
# dtype: int64

# %%
# Create a histogram of the "Px" feature and also show the mean and the median
px_mean = px.mean()
px_median = px.median()
plt.figure(figsize=(10,5))
sns.histplot(px, kde=True)
plt.axvline(px_mean, color='r', linestyle='--')
plt.axvline(px_median, color='g', linestyle='--')
plt.show()

# %%
# The children want phones that have good screen resolutions
# Consider the phones that have screen resolutions greater than or equal to the median value in the data set
# Create a logical condition for this situation and store the logical values as "con2"
con2=(px>=px.median())
con2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25     True
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "Px_h" and "Px_w" are respectively the number of pixels in the phone screen in the vertical and horizontal axes.
#
# We created a new feature called "Px" which is the product of the features "Px_h" and "Px_w".
#
# The median has been selected as a threshold in this case.
#
# In case it is too strict, we can choose the mean as a threshold.

# %% [markdown]
# # Task 4 - Obtain the logical conditions for the features "Scr_h" and "Scr_w"

# %%
# Let's tackle these features: "Scr_h", "Scr_w"
l2 = df.loc[:,["Scr_h","Scr_w"]]
l2
# Out:
#     Scr_h  Scr_w
# 0       3      1
# 1       2      1
# 2       2      1
# 3       5      3
# 4       4      3
# 5       4      3
# 6       6      3
# 7       8      6
# 8       6      3
# 9       5      3
# 10      6      3
# 11      8      6
# 12      6      5
# 13      6      5
# 14      5      3
# 15     10      8
# 16      8      6
# 17      8      6
# 18      8      6
# 19      4      3
# 20      4      3
# 21      8      6
# 22      4      3
# 23     10      8
# 24      6      4
# 25      6      3
# 26      5      3
# 27      8      6
# 28      8      6
# 29      8      6
# 30      8      6
# 31      8      6
# 32      8      6
# 33      8      6
# 34      6      3
# 35      5      3
# 36     10      8
# 37      5      3
# 38      5      3
# 39      6      5
# 40      5      3
# 41      8      6
# 42      8      6
# 43      8      6
# 44     10      8
# 45      8      6
# 46      4      3
# 47      8      6
# 48      8      6
# 49      8      6

# %%
# Create a new feature called "Scr_d" which stores the length of the diagonal of the screen of the phone
Scr_d= (df["Scr_h"]**2 + df["Scr_w"]**2)**0.5
Scr_d
# Out:
# 0      3.162278
# 1      2.236068
# 2      2.236068
# 3      5.830952
# 4      5.000000
# 5      5.000000
# 6      6.708204
# 7     10.000000
# 8      6.708204
# 9      5.830952
# 10     6.708204
# 11    10.000000
# 12     7.810250
# 13     7.810250
# 14     5.830952
# 15    12.806248
# 16    10.000000
# 17    10.000000
# 18    10.000000
# 19     5.000000
# 20     5.000000
# 21    10.000000
# 22     5.000000
# 23    12.806248
# 24     7.211103
# 25     6.708204
# 26     5.830952
# 27    10.000000
# 28    10.000000
# 29    10.000000
# 30    10.000000
# 31    10.000000
# 32    10.000000
# 33    10.000000
# 34     6.708204
# 35     5.830952
# 36    12.806248
# 37     5.830952
# 38     5.830952
# 39     7.810250
# 40     5.830952
# 41    10.000000
# 42    10.000000
# 43    10.000000
# 44    12.806248
# 45    10.000000
# 46     5.000000
# 47    10.000000
# 48    10.000000
# 49    10.000000
# dtype: float64

# %%
# Create a histogram of the "Scr_d" feature and also show the quartiles
Q1 =np.percentile(Scr_d, 25)
Q2 =np.percentile(Scr_d, 50)
Q3 =np.percentile(Scr_d, 75)

plt.figure(figsize=(10,5))
sns.histplot(Scr_d, kde=True,color='m')
plt.axvline(Q1, color='r', linestyle='--', label='Q1(25th percentile)')
plt.axvline(Q2, color='g', linestyle='--', label='Q2(50th percentile)')
plt.axvline(Q3, color='b', linestyle='--',  label='Q3(75th percentile)')
plt.legend()
plt.xlabel('Scr_d')
plt.ylabel('Frequency')
plt.title('Histogram of Scr_d with Quartiles')
plt.show()

# %%
# The children want phones that have very good screen sizes
# Consider the phones that have screen sizes greater than or equal to the upper quartile value in the data set
# Create a logical condition for this situation and store the logical values as "con3"
con3=(Scr_d>=Q3)
con3
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46    False
# 47     True
# 48     True
# 49     True
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "Scr_h" and "Scr_w" are respectively the height and the width of the phone screen.
#
# We created a new feature called "Scr_d" which is essentially the length of the screen diagonal.
#
# The upper quartile has been selected as a threshold in this case as the children were very particular on this point.
#
# In case it is too strict, we can choose the mean or the median as a threshold.

# %% [markdown]
# # Task 5 - Obtain the logical conditions for the features "PC" and "FC"

# %%
# Let's tackle these features: "PC", "FC"
l3 = df.loc[:,["PC","FC"]]
l3
# Out:
#      PC  FC
# 0     2   2
# 1     4   2
# 2     4   2
# 3     6   2
# 4     6   2
# 5     6   4
# 6     8   4
# 7    12   8
# 8    32  16
# 9    64  32
# 10   32  16
# 11   64  32
# 12   64  32
# 13   32  16
# 14   16   8
# 15   16  16
# 16   64  32
# 17    8   8
# 18   12   4
# 19   24  12
# 20   32  16
# 21   64  32
# 22    8   8
# 23    8   4
# 24    8   4
# 25   64  32
# 26    8   4
# 27   64  16
# 28   64  32
# 29   64  16
# 30   64  32
# 31   32  16
# 32   64  32
# 33   64  32
# 34   64  32
# 35   32  16
# 36   64  32
# 37   48  32
# 38   64  32
# 39   32  16
# 40   64  32
# 41   48  16
# 42   64  32
# 43   32  16
# 44   64  32
# 45   64  32
# 46   64  32
# 47   64  32
# 48  128  64
# 49  128  64

# %%
# Create a histogram of the "PC" feature and also show the mean and the median
mean_pc = df["PC"].mean()
median_pc = df["PC"].median()
plt.figure(figsize=(10,5))
sns.histplot(df["PC"], kde=True)
plt.axvline(mean_pc, color='r', linestyle='--')
plt.axvline(median_pc, color='g', linestyle='--')
plt.show()

# %%
# Create a histogram of the "FC" feature and also show the mean and the median
FC_mean = df["FC"].mean()
FC_median = df["FC"].median()
plt.figure(figsize=(10,5))
sns.histplot(df["FC"], kde=True,color='m')
plt.axvline(FC_mean, color='r', linestyle='--')
plt.axvline(FC_median, color='g', linestyle='--')
plt.show()

# %%
# The children want phones that have good primary and front camera resolutions
# Consider the phones that have primary and front camera resolutions greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con4"
PC_mean = df["PC"].mean()
FC_mean = df["FC"].mean()
con4=(df["PC"]>=PC_mean) & (df["FC"]>=FC_mean)
con4
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# 32     True
# 33     True
# 34     True
# 35    False
# 36     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "PC" and "FC" are respectively the resolutions of the primary camera and the front camera.
#
# The respective means have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective medians as thresholds.

# %% [markdown]
# # Task 6 - Obtain the logical conditions for the features "Int_Mem", "Bty_Pwr" and "RAM"

# %%
# Let's tackle these features: "Int_Mem", "Bty_Pwr", "RAM"
L4 = df.loc[:,["Int_Mem","Bty_Pwr","RAM"]]
L4
# Out:
#     Int_Mem  Bty_Pwr  RAM
# 0         8     2800    2
# 1         8     3000    2
# 2         8     3300    2
# 3        32     3000    2
# 4        16     3000    2
# 5         8     2980    2
# 6        32     3000    2
# 7        32     3200    2
# 8         8     2800    6
# 9        64     4380    4
# 10      128     2800    4
# 11        8     4500    8
# 12       64     4500    6
# 13       64     2800    6
# 14        8     2800    4
# 15      128     3900    6
# 16      128     3300    4
# 17       64     2800    4
# 18        8     4000    4
# 19       64     2800    4
# 20       16     2800    4
# 21      128     4400    4
# 22       64     2800    8
# 23       16     4800    8
# 24       32     2800    8
# 25       64     4500    8
# 26      128     4500    8
# 27       32     4300    8
# 28      512     4200    8
# 29      256     5000    8
# 30      512     4860    8
# 31      256     3300    8
# 32     1024     4860    8
# 33      128     2800    8
# 34      128     4400    8
# 35       64     2800    8
# 36       32     3000    4
# 37      128     4800    4
# 38       32     4860    8
# 39       32     3200    4
# 40      128     3000    4
# 41      128     3400    4
# 42     1024     5600    8
# 43      256     3900    4
# 44      512     4560    8
# 45       64     2300    4
# 46       64     2800    4
# 47      512     5600   12
# 48      512     5600   12
# 49     1024     5600   12

# %%
# Create a histogram of the "Int_Mem" feature and also show the mean and the median
Int_Mem_mean = df["Int_Mem"].mean()
Int_Mem_median = df["Int_Mem"].median()
plt.figure(figsize=(10,5))
sns.histplot(df["Int_Mem"], kde=True)
plt.axvline(Int_Mem_mean, color='r', linestyle='--')
plt.axvline(Int_Mem_median, color='g', linestyle='--')
plt.show()

# %%
# Create a histogram of the "Bty_Pwr" feature and also show the mean and the median
Bty_Pwr_mean = df["Bty_Pwr"].mean()
Bty_Pwr_median = df["Bty_Pwr"].median()
plt.figure(figsize=(10,8))
sns.histplot(df["Bty_Pwr"], kde=True,color='g')
plt.axvline(Bty_Pwr_mean, color='r', linestyle='--')
plt.axvline(Bty_Pwr_median, color='b', linestyle='--')
plt.show()

# %%
# Create a histogram of the "RAM" feature and also show the mean and the median
RAM_mean = df["RAM"].mean()
RAM_median = df["RAM"].median()
plt.figure(figsize=(10,5))
sns.histplot(df["RAM"], kde=True,color='k')
plt.axvline(RAM_mean, color='r', linestyle='--')
plt.axvline(RAM_median, color='g', linestyle='--')
plt.show()

# %%
# The children want phones that have good internal memory, battery power and RAM
# Consider the phones that have internal memory, battery power and RAM greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con5"
Int_Mem_mean = df["Int_Mem"].mean()
print("Mean of Internal Memory (GB):", Int_Mem_mean)
Bty_Pwr_mean = df["Bty_Pwr"].mean()
print("Mean of Battery Power (mAh):",Bty_Pwr_mean)
RAM_mean = df["RAM"].mean()
print("Mean of RAM (GB)",RAM_mean)
df["con5"] = (df["Int_Mem"] >= int(Int_Mem_mean)) & (df["Bty_Pwr"] >=
int(Bty_Pwr_mean)) & (df["RAM"] >= int(RAM_mean))
print(df[["PID","Int_Mem", "Bty_Pwr","RAM","con5"]])
# Out:
# Mean of Internal Memory (GB): 173.76
# Mean of Battery Power (mAh): 3740.0
# Mean of RAM (GB) 5.76
#          PID  Int_Mem  Bty_Pwr  RAM   con5
# 0    AAB346A        8     2800    2  False
# 1    AAC347I        8     3000    2  False
# 2    BAB657J        8     3300    2  False
# 3    BBD456K       32     3000    2  False
# 4    CCP761U       16     3000    2  False
# 5    CCQ674K        8     2980    2  False
# 6    CTX123L       32     3000    2  False
# 7    DFR256N       32     3200    2  False
# 8    DGS789M        8     2800    6  False
# 9    ENG897N       64     4380    4  False
# 10   EOP657N      128     2800    4  False
# 11   ELS333L        8     4500    8  False
# 12   ETT987D       64     4500    6  False
# 13   NAJ56GL       64     2800    6  False
# 14   NBN329S        8     2800    4  False
# 15   NSD450I      128     3900    6  False
# 16   PDF768G      128     3300    4  False
# 17   PDG234M       64     2800    4  False
# 18   PEL111K        8     4000    4  False
# 19  PNWD777L       64     2800    4  False
# 20   POP857R       16     2800    4  False
# 21   QWR222Y      128     4400    4  False
# 22   QZR577O       64     2800    8  False
# 23   RAY344W       16     4800    8  False
# 24   RBZ451D       32     2800    8  False
# 25   SDO555G       64     4500    8  False
# 26   SET568R      128     4500    8  False
# 27   SFK567Y       32     4300    8  False
# 28   SSD000L      512     4200    8   True
# 29   SYL888P      256     5000    8   True
# 30   TVF078Y      512     4860    8   True
# 31   TYQ109G      256     3300    8  False
# 32   TYS938L     1024     4860    8   True
# 33   TYU444Q      128     2800    8  False
# 34   TYY453J      128     4400    8  False
# 35   ULI999T       64     2800    8  False
# 36   UST000T       32     3000    4  False
# 37   USZ111S      128     4800    4  False
# 38   VWV532Y       32     4860    8  False
# 39   VYI666I       32     3200    4  False
# 40   WER765T      128     3000    4  False
# 41   WUV902Y      128     3400    4  False
# 42   WZB298K     1024     5600    8   True
# 43   XKL901R      256     3900    4  False
# 44   XTL675G      512     4560    8   True
# 45   XXV567F       64     2300    4  False
# 46   YTR67TY       64     2800    4  False
# 47   ZDF789K      512     5600   12   True
# 48   ZEO567M      512     5600   12   True
# 49   ZZZ909X     1024     5600   12   True

# %% [markdown]
# Observations
#
# The features "Int_Mem", "Bty_Pwr" and "RAM" are respectively the internal memory, battery power and RAM of the phones.
#
# The respective means have been selected as thresholds in this case.
#
# .In case it is too strict, we can choose the respective medians as thresholds

# %% [markdown]
# # Task 7 - Obtain the logical conditions for the features "Depth" and "Weight"

# %%
# Let's tackle these features: "Depth", "Weight"
l5 = df.loc[:,["Depth", "Weight"]]
l5
# Out:
#     Depth  Weight
# 0       7     320
# 1       7     280
# 2       7     400
# 3       3     300
# 4       3     210
# 5       3     230
# 6       3     100
# 7       3      80
# 8       3     120
# 9       3     150
# 10      4     210
# 11      4     150
# 12      4     300
# 13      4     270
# 14      4      80
# 15      4     180
# 16      3     160
# 17      3     250
# 18      3     330
# 19      3     200
# 20      3     150
# 21      3     160
# 22      3     170
# 23      3     170
# 24      3     150
# 25      3     210
# 26      3     220
# 27      3     200
# 28      3     270
# 29      3     320
# 30      3      90
# 31      3     110
# 32      3     120
# 33      3     120
# 34      4     150
# 35      4     210
# 36      4     240
# 37      4     230
# 38      4     310
# 39      4     180
# 40      4     120
# 41      3     140
# 42      3     160
# 43      3     210
# 44      3     260
# 45      3     250
# 46      3     200
# 47      2      80
# 48      2     110
# 49      2     130

# %%
# Create a histogram of the "Depth" feature and also show the mean and the median
plt.figure(figsize = (9,6))
sns.histplot(data = df, x= df["Depth"],color = "orange",edgecolor =
'linen',bins=10, kde= False)
plt.title("Histogram of Depth")
plt.xlabel("Depth (cm)")
plt.ylabel("count")
plt.vlines(df["Depth"].mean(), ymin=0, ymax=50, color = "green", label = "Mean")
plt.vlines(df["Depth"].median(), ymin=0, ymax=50, color = "red", label =
"Median")
plt.legend()
plt.show()

# %%
# Create a histogram of the "Weight" feature and also show the mean and the median
plt.figure(figsize = (9,6))
sns.histplot(data = df, x= df["Weight"],color = "orange",edgecolor =
'linen',bins=10, kde= False,alpha=0.5)
plt.title("Histogram of Weight")
plt.xlabel("Weight (g)")
plt.ylabel("count")
plt.vlines(df["Weight"].mean(), ymin=0, ymax=50, color = "blue", label = "Mean")
plt.vlines(df["Weight"].median(), ymin=0, ymax=50, color = "red", label =
"Median")
plt.legend()
plt.show()

# %%
# The children want phones that are light weight and slim
# Consider the phones that have depth and weight less than or equal to the respective median values in the data set
# Create a logical condition for this situation and store the logical values as "con6"
depth_median = df["Depth"].median()
print("Median of Depth(cm):",depth_median)
weight_median = df["Weight"].median()
print("Median of Weight(g)",weight_median)
df["con6"] = (df["Depth"] <= int(depth_median)) & (df["Weight"] <=
int(weight_median))
print(df[["PID","Depth","Weight","con6"]])
# Out:
# Median of Depth(cm): 3.0
# Median of Weight(g) 190.0
#          PID  Depth  Weight   con6
# 0    AAB346A      7     320  False
# 1    AAC347I      7     280  False
# 2    BAB657J      7     400  False
# 3    BBD456K      3     300  False
# 4    CCP761U      3     210  False
# 5    CCQ674K      3     230  False
# 6    CTX123L      3     100   True
# 7    DFR256N      3      80   True
# 8    DGS789M      3     120   True
# 9    ENG897N      3     150   True
# 10   EOP657N      4     210  False
# 11   ELS333L      4     150  False
# 12   ETT987D      4     300  False
# 13   NAJ56GL      4     270  False
# 14   NBN329S      4      80  False
# 15   NSD450I      4     180  False
# 16   PDF768G      3     160   True
# 17   PDG234M      3     250  False
# 18   PEL111K      3     330  False
# 19  PNWD777L      3     200  False
# 20   POP857R      3     150   True
# 21   QWR222Y      3     160   True
# 22   QZR577O      3     170   True
# 23   RAY344W      3     170   True
# 24   RBZ451D      3     150   True
# 25   SDO555G      3     210  False
# 26   SET568R      3     220  False
# 27   SFK567Y      3     200  False
# 28   SSD000L      3     270  False
# 29   SYL888P      3     320  False
# 30   TVF078Y      3      90   True
# 31   TYQ109G      3     110   True
# 32   TYS938L      3     120   True
# 33   TYU444Q      3     120   True
# 34   TYY453J      4     150  False
# 35   ULI999T      4     210  False
# 36   UST000T      4     240  False
# 37   USZ111S      4     230  False
# 38   VWV532Y      4     310  False
# 39   VYI666I      4     180  False
# 40   WER765T      4     120  False
# 41   WUV902Y      3     140   True
# 42   WZB298K      3     160   True
# 43   XKL901R      3     210  False
# 44   XTL675G      3     260  False
# 45   XXV567F      3     250  False
# 46   YTR67TY      3     200  False
# 47   ZDF789K      2      80   True
# 48   ZEO567M      2     110   True
# 49   ZZZ909X      2     130   True

# %% [markdown]
# Observations:
#
# The features "Depth" and "Weight" are respectively the depth of the phone and the weight of the phone.
#
# The respective medians have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective means as thresholds.

# %% [markdown]
# # Task 8 - Subset the data based on all the logical conditions

# %%
# Subset the dataframe using all the logical conditions that have been stored
# Store the subset of the dataframe as a new dataframe called "df1"
df = pd.DataFrame(data)

# Filter the DataFrame
df1 = df[(df['con1']) & (df['con2']) & (df['con3']) & (df['con4']) & (df['con5']) & (df['con6'])]

print(df1)
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  Weight  \
# 0  TVF078Y  yes   yes     yes     yes  2580  2120      8      6  64      90
# 1  TYS938L  yes   yes     yes     yes  2580  2120      8      6  64     120
# 2  WZB298K  yes   yes     yes     yes  2580  1980      8      6  64     160
#
#    Price  con1       Px  con2  Scr_d  con3  con4  con5  con6
# 0  29999  True  5469600  True   10.0  True  True  True  True
# 1  46777  True  5469600  True   10.0  True  True  True  True
# 2  39000  True  5108400  True   10.0  True  True  True  True

# %%
# Get the dimensions of the dataframe
df1 .shape
# Out:
# (3, 20)

# %%
# Sort the dataframe according to the "Price" feature in ascending order and display it
df1_sorted = df1.sort_values(by="Price", ascending= True)
df1_sorted
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  Weight  \
# 0  TVF078Y  yes   yes     yes     yes  2580  2120      8      6  64      90
# 2  WZB298K  yes   yes     yes     yes  2580  1980      8      6  64     160
# 1  TYS938L  yes   yes     yes     yes  2580  2120      8      6  64     120
#
#    Price  con1       Px  con2  Scr_d  con3  con4  con5  con6
# 0  29999  True  5469600  True   10.0  True  True  True  True
# 2  39000  True  5108400  True   10.0  True  True  True  True
# 1  46777  True  5469600  True   10.0  True  True  True  True

# %% [markdown]
# Observations:
#
# Based on all the logical conditions obtained through analysis of the features, we are left with three phones.
#
# The most expensive of these phones is the "TYS938L" model and the least expensive is the "TVF078Y" model.
#
# We could let the children choose from these three phones as per their preferences.

# %% [markdown]
# # Task 9 - Study the variability of the features in the original data set

# %%
# Calculate the ratio of the standard deviation to the mean for all the numerical features in the dataframe
# Store these values in a new series wherein the rows are the features and the only column is the calculated ratio
# Name the series as "deviations"
deviations = df.select_dtypes(include=['number']).std() / df.select_dtypes(include=['number']).mean()
deviations.name = 'deviations'

# %%
# View the "deviations" series after sorting it in descending order
deviations = deviations.sort_values(ascending= False)
deviations
# Out:
# Weight    0.284747
# Price     0.217569
# Px_w      0.038985
# Px        0.038985
# Px_h      0.000000
# Scr_h     0.000000
# Scr_w     0.000000
# PC        0.000000
# Scr_d     0.000000
# Name: deviations, dtype: float64

# %% [markdown]
# Observations:
#
# The ratio of the standard deviation to the mean of a feature normalises it in a way.
#
# This allows for comparison between multiple features.
#
# The most variable feature in the original data set is the internal memory of the phones.
#
# The least variable feature in the original data set is the number of screen pixels in the horizontal axis.
#
# Although most features don't seem so variable, the prices of the phones are quite variable.
#
# Feel free to investigate what could be the cause of this difference in variability.
#
# Note: We encourage you to extend this analysis further and see what else you can find.
#
# Note: Please refer to the official website of Python and its libraries for various Python documentations.

# %% [markdown]
# # Conclusion
# 1. We have used concepts of descriptive statistics to study and work with a data set that contains mobile phone specifications.
#
# 2. We were able to recommend three phone models to the client which she can then propose to her children.
